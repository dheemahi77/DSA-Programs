# %% [markdown]
# <a href="https://colab.research.google.com/github/dheemahi77/DSA-Programs/blob/main/Day_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#collection in queue
#implementation of queue using stacks
from collections import Counter
numbers=[1,2,2,2,2,3,3,4,5,5,5,6]
c=Counter(numbers)
print(c)
print(c[6])
# Out:
# Counter({2: 4, 5: 3, 3: 2, 1: 1, 4: 1, 6: 1})
# 1

# %%
#collection in queue
#implementation of queue using stacks
from collections import defaultdict,UserDict
d=defaultdict(int)
d['Orange']+=1
d['Apple']+=1
d['Mango']+=1
d['Apple']+=1
print(d)
d=UserDict({'A':10,'B':1000,'A':100})
print(d)
# Out:
# defaultdict(<class 'int'>, {'Orange': 1, 'Apple': 2, 'Mango': 1})
# {'A': 100, 'B': 1000}

# %%
from collections import UserList,UserString
numbers=UserList([1,2,3])
numbers.append(4)
print(numbers)
s=UserString("mahi")
print(s)
# Out:
# [1, 2, 3, 4]
# mahi

# %%
from typing import ChainMap
from collections import namedtuple,UserList,UserString
student=namedtuple("student",["name","age"])
s=student("mahi",21)
print(s.name)
print(s.age)
d1={"A":10}
d2={"B":11}
d=ChainMap(d1,d2)
print(d["A"])
print(d["B"])
# Out:
# mahi
# 21
# 10
# 11

# %%
#implementation of queue operations using stacks
stack1=[]
stack2=[]
def enqueue(val):
  stack1.append(val)
def dequeue():
  if len(stack1)==0:
    print("Queue underflow")
  else:
    while stack1:
      stack2.append(stack1.pop())
    print("Removed:",stack2.pop())
    while stack2:
      stack1.append(stack2.pop())
n=int(input("Enter number of elements:"))
for i in range(n):
  val=int(input("Enter value:"))
  enqueue(val)
print("Queue",stack1)
dequeue()
print("After Deleting from Queue",stack1)
# Out:
# Enter number of elements:4
# Enter value:11
# Enter value:2
# Enter value:33
# Enter value:44
# Queue [11, 2, 33, 44]
# Removed: 11
# After Deleting from Queue [2, 33, 44]
