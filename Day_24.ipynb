# %% [markdown]
# <a href="https://colab.research.google.com/github/dheemahi77/DSA-Programs/blob/main/Day_24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#create a circular linked list
size=int(input("enter queue size:"))
queue=[0]*size
print(queue)
front=-1
rear=-1
n=int(input("enter number of elements:"))
for i in range(n):
  value=int(input("enter value:"))
  if (rear+1)%size==front:
    print("Queue overflow")
    break
  if front==-1:
    front=0
  rear=(rear+1)%size
  queue[rear]=value
print("circular queue")
if front==-1:
  print("queue underflow")
else:
  i=front
  while True:
    print(queue[i],end=" ")
    if i==rear:
      break
    i=(i+1)%size
  print(queue[0])
# Out:
# enter queue size:4
# [0, 0, 0, 0]
# enter number of elements:3
# enter value:1
# enter value:2
# enter value:3
# circular queue
# 1 2 3 1

# %%
# create a circular queue  traversal
size = int(input("enter queue size: "))
queue= [0] *size
print(queue)
front = -1
rear = -1
n= int(input("Enter number of elements : "))
for i in range(n):
    value= int(input("Enter value : "))
    if (rear+1)%size== front :
        print("Queue Overflow.....")
        break
    if front == -1:
        front = 0
    rear= (rear+1)%size
    queue[rear]= value
print("Circular Queue : ")
if front == -1 :
    print("Queue underflow..")
else:
    start= int(input("Enter starting value "))
    i= front
    start_index= -1
    while True:
        if queue[i]== start:
            start_index= i
            break
        if i==rear:
            break
        i=(i+1)%size
    if start_index==-1:
        print("Element not found ")
    else:
        print("Circular traversal ")
    i= start_index
    while True:
        print(queue[i], end=' ')
        if i==rear:
            i= front
            while i!= start_index:
                print(queue[i], end=' ')
                i=(i+1)%size
            break
        i=(i+1)%size
# Out:
# enter queue size: 4
# [0, 0, 0, 0]
# Enter number of elements : 3
# Enter value : 2
# Enter value : 3
# Enter value : 4
# Circular Queue :
# Enter starting value 3
# Circular traversal
# 3 4 2

# %%
#create a circular queue traversal
queue=list(map(int,input("enter elements:").split()))
start=int(input("enter start value:"))
if start not in queue:
  print("element not found")
else:
  index=queue.index(start)
  for i in range(len(queue)):
    print(queue[(index+i)%len(queue)],end=" ")
# Out:
# enter elements:4
# enter start value:3
# element not found
