# %% [markdown]
# <a href="https://colab.research.google.com/github/dheemahi77/DSA-Programs/blob/main/Day_17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Doubly linked list
class node:
  def __init__(self,data):
    self.data=data
    self.prev=None
    self.next=None
head=None
tail=None
n=int(input("Enter the size of DLL:"))
for i in range(n):
  data=int(input("Enter value:"))
  newnode=node(data)
  if head is None:
    head=newnode
    tail=newnode
  else:
    tail.next=newnode
    newnode.prev=tail
    tail=newnode
print("\n Forward traversal:")
temp=head
while temp is not None:
  print(temp.data,end="<->")
  temp=temp.next
print("Tail")
print("\n Backward traversal:")
temp=tail
while temp is not None:
  print(temp.data,end="<->")
  temp=temp.prev
print("Tail")
# Out:
# Enter the size of DLL:5
# Enter value:11
# Enter value:22
# Enter value:33
# Enter value:44
# Enter value:55
#
#  Forward traversal:
# 11<->22<->33<->44<->55<->Tail
#
#  Backward traversal:
# 55<->44<->33<->22<->11<->Tail

# %%
#traversal in ddl
class node:
  def __init__(self,data):
    self.data=data
    self.prev=None
    self.next=None
head=None
tail=None
n=int(input("Enter the size of DLL:"))
for i in range(n):
  data=int(input("Enter value:"))
  newnode=node(data)
  if head is None:
    head=newnode
    tail=newnode
  else:
    newnode.next=head
    head.prev=newnode
    head=newnode
print("\n traversal:")
temp=head
while temp is not None:
  print(temp.data,end="<->")
  temp=temp.next
print("Tail")
print("\n Backward traversal:")
temp=tail
while temp is not None:
  print(temp.data,end="<->")
  temp=temp.prev
print("Tail")
# Out:
# Enter the size of DLL:4
# Enter value:11
# Enter value:22
# Enter value:33
# Enter value:44
#
#  traversal:
# 44<->33<->22<->11<->Tail
#
#  Backward traversal:
# 11<->22<->33<->44<->Tail

# %%
#insert at beginning and delete at end
class node:
  def __init__(self,data):
    self.data=data
    self.prev=None
    self.next=None
head=None
tail=None
n=int(input("Enter the size of DLL:"))
for i in range(n):
  data=int(input("Enter value:"))
  newnode=node(data)
  if head is None:
    head=newnode
    tail=newnode
  else:
    newnode.next=head
    head.prev=newnode
    head=newnode
print("\n traversal:")
temp=head
while temp is not None:
  print(temp.data,end="<->")
  temp=temp.next
print("tail")
if head is None:
  print("DLL is empty")
elif head.next is None:
  head=None
  tail=None
else:
  tail=tail.prev
  tail.next=None
print("\n after deleting at end :")
temp=head
while temp is not None:
  print(temp.data,end="<->")
  temp=temp.next
print("Tail")
# Out:
# Enter the size of DLL:4
# Enter value:11
# Enter value:22
# Enter value:33
# Enter value:44
#
#  traversal:
# 44<->33<->22<->11<->tail
#
#  after deleting at end :
# 44<->33<->22<->Tail

# %%
# Doubly Linked List
# Insert at end and delete at begin
class node:
    def __init__(self, data):
        self.data = data
        self.prev = None
        self.next = None
head = None
tail = None
n = int(input("Enter the size of DLL: "))
for i in range(n):
    data = int(input("Enter value: "))
    newnode = node(data)
    if head is None:
        head = newnode
        tail = newnode
    else:
        tail.next = newnode
        newnode.prev = tail
        tail = newnode
print("\nForward traversal:")
temp = head
while temp is not None:
    print(temp.data, end="<->")
    temp = temp.next
print("Tail")

if head is None:
    print("DLL is empty")
elif head.next is None:
    head = None
    tail = None
else:
    head=head.next
    head.prev=None
print("\nAfter deleting at end:")
temp = head
while temp is not None:
    print(temp.data, end="<->")
    temp = temp.next
print("Tail")
# Out:
# Enter the size of DLL: 4
# Enter value: 11
# Enter value: 22
# Enter value: 33
# Enter value: 44
#
# Forward traversal:
# 11<->22<->33<->44<->Tail
#
# After deleting at end:
# 22<->33<->44<->Tail

# %%
#Insert at end and delete at begin ------>Reverse
class node:
    def __init__(self, data):
        self.data = data
        self.prev = None
        self.next = None
head = None
tail = None
n = int(input("Enter the size of DLL: "))
for i in range(n):
    data = int(input("Enter value: "))
    newnode = node(data)
    if head is None:
        head = newnode
        tail = newnode
    else:
        tail.next = newnode
        newnode.prev = tail
        tail = newnode
print("\nForward traversal:")
temp = head
while temp is not None:
    print(temp.data, end="<->")
    temp = temp.next
print("Tail")
print("\n Backward traversal:")
temp=tail
while temp is not None:
  print(temp.data,end="<->")
  temp=temp.prev
print("Tail")
if head is None:
    print("DLL is empty")
elif head.next is None:
    head = None
    tail = None
else:
    head=head.next
    head.prev=None
print("\nAfter deleting at begining:")
temp = head
while temp is not None:
    print(temp.data, end="<->")
    temp = temp.next
print("Tail")
print("\n Backward traversal:")
temp=tail
while temp is not None:
  print(temp.data,end="<->")
  temp=temp.prev
print("Tail")
# Out:
# Enter the size of DLL: 4
# Enter value: 11
# Enter value: 22
# Enter value: 33
# Enter value: 44
#
# Forward traversal:
# 11<->22<->33<->44<->Tail
#
#  Backward traversal:
# 44<->33<->22<->11<->Tail
#
# After deleting at begining:
# 22<->33<->44<->Tail
#
#  Backward traversal:
# 44<->33<->22<->Tail
