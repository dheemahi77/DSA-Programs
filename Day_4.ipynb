# %% [markdown]
# <a href="https://colab.research.google.com/github/dheemahi77/DSA-Programs/blob/main/Day_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Functions**

# %%
#1.argument pass return value
def sum(a,b):
  return a+b
n1=int(input("enetr a first value:"))
n2=int(input("enter a second value:"))
result=sum(n1,n2)
print("sum:",result)
# Out:
# enetr a first value:7
# enter a second value:9
# sum: 16

# %%
#2.argument pass no return value
def sum(n1,n2):
  print("sum:",n1+n2)
n1=int(input("enter a value:"))
n2=int(input("enter a value:"))
sum(n1,n2)
# Out:
# enter a value:3
# enter a value:5
# sum: 8

# %%
#3.no arg return value
def sum():
  n1=int(input("enetr no1:"))
  n2=int(input("enter no2:"))
  return n1+n2
result=sum()
print("sum:",result)
# Out:
# enetr no1:3
# enter no2:6
# sum: 9

# %%
#4.no arg no return
def sum():
  n1=int(input("enter a value:"))
  n2=int(input("enter a value:"))
  print("sum:",n1+n2)
sum()
# Out:
# enter a value:3
# enter a value:5
# sum: 8

# %% [markdown]
# # **Recursion**

# %%
#1.direct
#2.indirect
#3.tail
#4.head
#5.tree
#6.nested

# %%
#1.direct recursion
#code to print n natural numbers using direct recursion
def numbers(n):
  if n==0:
    return
  print(n,end=" ")
  numbers(n-1)
n=int(input("enter a number:"))
numbers(n)
# Out:
# enter a number:5
# 5 4 3 2 1

# %%
#2.indirect
#code to check the given number is even or odd using in direct recursion
def even(n):
  if n==0:
    print("even")
    return
  odd(n-1)
def odd(n):
  if n==0:
    print("odd")
    return
  even(n-1)
n=int(input("enter a number:"))
even(n)
# Out:
# enter a number:6
# even

# %%
#tree recursion using fibanocci number
def fib(n):
  if n<=1:
    return n
  return fib(n-1)+fib(n-2)
n=int(input("enter a number:"))
print("fibanocci:",fib(n))
# Out:
# enter a number:5
# fibanocci: 5
